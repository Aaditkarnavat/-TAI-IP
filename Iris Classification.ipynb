# %% [markdown]
# <a href="https://colab.research.google.com/github/Aaditkarnavat/-TAI-IP/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The aim is to classify iris flowers among three species(Setosa versicolor and virginica) from measurements of sepals and petals length and width
#
# The data source is in iris.csv  and contains 3 classes of 50 instances each where each class refers to type of iris plant.
#
# The data set is in the CSV form and contains 5 columns and 50 rows.

# %% [markdown]
# 1) IMPORTING LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# 2)LOADING THE DATASET

# %%
columns= ['Sepal length','Sepal Width' , 'Petal Length' , 'Petal Width',' Class_labels']
iris = pd.read_csv("Iris.csv",names=columns )
iris.head(150)
# Out:
#       Sepal length   Sepal Width   Petal Length   Petal Width    Class_labels
# Id   SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 1              5.1           3.5            1.4           0.2     Iris-setosa
# 2              4.9           3.0            1.4           0.2     Iris-setosa
# 3              4.7           3.2            1.3           0.2     Iris-setosa
# 4              4.6           3.1            1.5           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.3            5.7           2.5  Iris-virginica
# 146            6.7           3.0            5.2           2.3  Iris-virginica
# 147            6.3           2.5            5.0           1.9  Iris-virginica
# 148            6.5           3.0            5.2           2.0  Iris-virginica
# 149            6.2           3.4            5.4           2.3  Iris-virginica
#
# [150 rows x 5 columns]
# ...

# %% [markdown]
# VISUALISATION OF DATASET

# %%
iris.describe()
# Out:
#        Sepal length Sepal Width Petal Length Petal Width  Class_labels
# count           151         151          151         151           151
# unique           36          24           44          23             4
# top             5.0         3.0          1.5         0.2   Iris-setosa
# freq             10          26           14          28            50
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_31.groupby('Sepal length').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_32.groupby('Sepal Width').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
import missingno as msno
msno.bar(iris)
# Out:
# <Axes: >

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 151 entries, Id to 150
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sepal length   151 non-null    object
#  1   Sepal Width    151 non-null    object
#  2   Petal Length   151 non-null    object
#  3   Petal Width    151 non-null    object
#  4    Class_labels  151 non-null    object
# dtypes: object(5)
# memory usage: 7.1+ KB

# %%
iris.shape
# Out:
# (151, 5)

# %%
iris.isnull().sum()
# Out:
# Sepal length     0
# Sepal Width      0
# Petal Length     0
# Petal Width      0
#  Class_labels    0
# dtype: int64
